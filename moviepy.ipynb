# %%
from moviepy.editor import *

# %%
clip=VideoFileClip(r'13[도깨비_OST_Part_14]_헤이즈_(Heize)_-_Round_and_round_(Feat._한수지).mp4')

# %%
clip.size
# Out:
# [640, 360]

# %%
clip.duration
# Out:
# 201.09

# %%
durations(clip.duration)
# Out:
# (3, -0.005858333333333336)

# %%
clip.fps
# Out:
# 30.0

# %%
subclip1=clip.subclip(t_start=(0,0,0),t_end=(0,0,30))

# %%
subclip1.ipython_display()
# Out:
# chunk:   5%|▍         | 32/662 [00:00<00:03, 197.18it/s, now=None]
# Moviepy - Building video __temp__.mp4.
# MoviePy - Writing audio in __temp__TEMP_MPY_wvf_snd.mp3
# t:   5%|▌         | 48/900 [00:00<00:01, 473.22it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
subclip1.write_videofile(r'subclip1.mp4')
# Out:
# chunk:   0%|          | 2/662 [00:00<00:44, 14.77it/s, now=None]
# Moviepy - Building video subclip1.mp4.
# MoviePy - Writing audio in subclip1TEMP_MPY_wvf_snd.mp3
# t:   3%|▎         | 26/900 [00:00<00:03, 254.90it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video subclip1.mp4
# Moviepy - Done !
# Moviepy - video ready subclip1.mp4

# %%
subclip1.volumex(0.7) # for volum increase or decrese

# %%
from moviepy.editor import *

# %%
clip=VideoFileClip(r'13[도깨비_OST_Part_14]_헤이즈_(Heize)_-_Round_and_round_(Feat._한수지).mp4')

# %%
import datetime

# %%
def durations(duration):
    conversion = datetime.timedelta(seconds=duration)
    return str(conversion)

# %%
durations(clip.duration)
# Out:
# '0:03:21.090000'

# %%
from datetime import datetime
from datetime import timedelta

start = datetime(00, 00, 00)
end = datetime(00, 3, 21)
while start < end:
    print(start)
    start += timedelta(seconds=30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-dbc46cd79b77> in <module>
#       2 from datetime import timedelta
#       3
# ----> 4 start = datetime(00, 00, 00)
#       5 end = datetime(00, 3, 21)
#       6 while start < end:
#
# ValueError: year 0 is out of range

# %%
start
# Out:
# datetime.time(0, 0)

# %%
end
# Out:
# datetime.time(0, 3, 21)

# %%
mid=time(00,00,30)

# %%
start+mid
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-a38fe2557ea8> in <module>
# ----> 1 start+mid
#
# TypeError: unsupported operand type(s) for +: 'datetime.time' and 'datetime.time'

# %%
from time import time

# %%
time()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-ee5a8833922f> in <module>
# ----> 1 time(200)
#
# TypeError: time() takes no arguments (1 given)
